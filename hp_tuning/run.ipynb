# %% [markdown]
# # Hyperparameter tuning
# This notebook tunes the Hyperparameters of the DMD variants (like the rank of the SVD, the time-delay embedding, etc.) using a brute force approach, due to the quickness of the training process.

# %%
import yaml
import os
import numpy as np

from IPython.display import clear_output as clc

class TuneDMDs:
    """
    Basic Class
    """
    def __init__(self, pair_id=None):
        if pair_id is None:
            self.pair_id = [1, 2, 3, 4, 5, 6, 7]
        else:
            self.pair_id = pair_id

    def _create_yaml(self, rank: int, filename: str):
        
        assert isinstance(rank, int), "Rank must be an integer"
        assert rank == -1 or rank >= 0, "Rank must be a positive integer or -1"

        data = {
            'dataset': {
                'name': 'PDE_KS',
                'pair_id': self.pair_id
            },
            'model': {
                'name': 'DMD',
                'method': 'classic',
                'rank': rank
            }
        }

        with open(filename, 'w') as f:
            yaml.dump(data, f, sort_keys=False)

    def _run_yaml(self, filename: str):
        """
        Run the yaml file
        """
        os.system(f"python ../run.py {filename}")

    def test_hp(self, ranks: list):
        """
        Test the hyperparameters
        """
        
        for r in ranks:
            filename = f"../config/HPTuning/ClassicDMD/tunedmd_rank_{r}.yaml"
            os.makedirs(os.path.dirname(filename), exist_ok=True)
            self._create_yaml(r, filename)

            self._run_yaml(filename)

            clc()

# %% [markdown]
# ## Classic DMD
# This is for non-parametric datasets (id from 1 to 7). The hyperparameters are:
# - `rank`: the rank of the SVD

# %%
# import numpy as np

# ranks_to_test = np.arange(0, 401, 25)
# ranks_to_test = ranks_to_test.tolist()

# tune_dmd = TuneDMDvariants()
# tune_dmd.test_hp(ranks_to_test)

# %% [markdown]
# ## High-Order DMD
# This is for parametric datasets (id from 1 to 7). The hyperparameters are:
# - `rank`: the rank of the SVD
# - `time_delay`: the time-delay embedding

# %%
# class TuneHankelDMD(TuneDMDvariants):
#     """
    
#     """
#     def __init__(self, pair_id=None):
#         if pair_id is None:
#             self.pair_id = [1, 2, 3, 4, 5, 6, 7]
#         else:
#             self.pair_id = pair_id

#     def _create_yaml(self, rank: int, delay: int, filename: str):
        
#         assert isinstance(rank, int), "Rank must be an integer"
#         assert rank == -1 or rank >= 0, "Rank must be a positive integer or -1"

#         assert isinstance(delay, int), "Delay must be an integer"
#         assert delay >= 0, "Delay must be a positive integer"

#         data = {
#             'dataset': {
#                 'name': 'PDE_KS',
#                 'pair_id': self.pair_id
#             },
#             'model': {
#                 'name': 'DMD',
#                 'method': 'highorder',
#                 'rank': rank,
#                 'delay': delay
#             }
#         }

#         with open(filename, 'w') as f:
#             yaml.dump(data, f, sort_keys=False)

#     def test_hp(self, ranks: list, delays: list):
#         """
#         Test the hyperparameters
#         """
        
#         for r in ranks:
#             for d in delays:
#                 filename = f"../config/HPTuning/HankelDMD/tunedmd_rank{r}_delay{d}.yaml"
#                 os.makedirs(os.path.dirname(filename), exist_ok=True)
#                 self._create_yaml(r, d, filename)

#                 self._run_yaml(filename)

#                 clc()
    
# tune_dmd = TuneHankelDMD()

# ranks = np.arange(200, 351, 25).tolist()
# delays = np.arange(30, 41, 5).tolist()

# tune_dmd.test_hp(ranks, delays)

# %% [markdown]
# ## Optimised DMD
# This is for parametric datasets (id from 1 to 7). The hyperparameters are:
# - `rank`: the rank of the SVD
# - `time_delay`: the time-delay embedding
#
# (For the moment)

# %%
class TuneOptDMD(TuneDMDs):
    """
    
    """
    def __init__(self, pair_id=None):
        if pair_id is None:
            self.pair_id = [1, 2, 3, 4, 5, 6, 7]
        else:
            self.pair_id = pair_id

    def _create_yaml(self, rank: int, delay: int, filename: str):
        
        assert isinstance(rank, int), "Rank must be an integer"
        assert rank == -1 or rank >= 0, "Rank must be a positive integer or -1"

        assert isinstance(delay, int), "Delay must be an integer"
        assert delay >= 0, "Delay must be a positive integer"

        data = {
            'dataset': {
                'name': 'PDE_KS',
                'pair_id': self.pair_id
            },
            'model': {
                'name': 'DMD',
                'method': 'bagopt',
                'rank': rank,
                'eig_constraints': ['stable'],
                'delay': delay,
            }
        }

        with open(filename, 'w') as f:
            yaml.dump(data, f, sort_keys=False)

    def test_hp(self, ranks: list, delays: list):
        """
        Test the hyperparameters
        """
        
        for r in ranks:
            for d in delays:
                filename = f"../config/HPTuning/OptDMD/tunedmd_rank{r}_delay{d}.yaml"
                os.makedirs(os.path.dirname(filename), exist_ok=True)
                self._create_yaml(r, d, filename)

                self._run_yaml(filename)

                clc()
    
tune_dmd = TuneOptDMD()

ranks = [20, 40, 60]
delays = [10,20,30]

tune_dmd.test_hp(ranks, delays)
# Out:
# Running bagoptDMD on PDE_KS pair 1
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay10_numtrials0_20250423_180505/pair1/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay10_numtrials0_20250423_180505/pair1/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 2
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay10_numtrials0_20250423_180505/pair2/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay10_numtrials0_20250423_180505/pair2/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 3
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay10_numtrials0_20250423_180505/pair3/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay10_numtrials0_20250423_180505/pair3/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 4
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay10_numtrials0_20250423_180505/pair4/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay10_numtrials0_20250423_180505/pair4/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 5
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay10_numtrials0_20250423_180505/pair5/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay10_numtrials0_20250423_180505/pair5/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 6
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay10_numtrials0_20250423_180505/pair6/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay10_numtrials0_20250423_180505/pair6/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 7
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay10_numtrials0_20250423_180505/pair7/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay10_numtrials0_20250423_180505/pair7/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 1
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay20_numtrials0_20250423_180539/pair1/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay20_numtrials0_20250423_180539/pair1/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 2
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay20_numtrials0_20250423_180539/pair2/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay20_numtrials0_20250423_180539/pair2/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 3
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay20_numtrials0_20250423_180539/pair3/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay20_numtrials0_20250423_180539/pair3/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 4
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay20_numtrials0_20250423_180539/pair4/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay20_numtrials0_20250423_180539/pair4/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 5
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay20_numtrials0_20250423_180539/pair5/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay20_numtrials0_20250423_180539/pair5/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 6
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay20_numtrials0_20250423_180539/pair6/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay20_numtrials0_20250423_180539/pair6/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 7
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay20_numtrials0_20250423_180539/pair7/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay20_numtrials0_20250423_180539/pair7/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 1
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay30_numtrials0_20250423_180617/pair1/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay30_numtrials0_20250423_180617/pair1/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 2
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay30_numtrials0_20250423_180617/pair2/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay30_numtrials0_20250423_180617/pair2/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 3
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay30_numtrials0_20250423_180617/pair3/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay30_numtrials0_20250423_180617/pair3/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 4
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay30_numtrials0_20250423_180617/pair4/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay30_numtrials0_20250423_180617/pair4/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 5
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay30_numtrials0_20250423_180617/pair5/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay30_numtrials0_20250423_180617/pair5/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 6
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay30_numtrials0_20250423_180617/pair6/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay30_numtrials0_20250423_180617/pair6/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 7
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay30_numtrials0_20250423_180617/pair7/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank20_delay30_numtrials0_20250423_180617/pair7/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 1
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay10_numtrials0_20250423_180704/pair1/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay10_numtrials0_20250423_180704/pair1/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 2
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay10_numtrials0_20250423_180704/pair2/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay10_numtrials0_20250423_180704/pair2/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 3
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay10_numtrials0_20250423_180704/pair3/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay10_numtrials0_20250423_180704/pair3/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 4
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay10_numtrials0_20250423_180704/pair4/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay10_numtrials0_20250423_180704/pair4/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 5
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay10_numtrials0_20250423_180704/pair5/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay10_numtrials0_20250423_180704/pair5/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 6
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay10_numtrials0_20250423_180704/pair6/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay10_numtrials0_20250423_180704/pair6/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 7
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay10_numtrials0_20250423_180704/pair7/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay10_numtrials0_20250423_180704/pair7/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 1
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay20_numtrials0_20250423_180755/pair1/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay20_numtrials0_20250423_180755/pair1/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 2
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay20_numtrials0_20250423_180755/pair2/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay20_numtrials0_20250423_180755/pair2/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 3
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay20_numtrials0_20250423_180755/pair3/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay20_numtrials0_20250423_180755/pair3/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 4
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay20_numtrials0_20250423_180755/pair4/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay20_numtrials0_20250423_180755/pair4/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 5
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay20_numtrials0_20250423_180755/pair5/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay20_numtrials0_20250423_180755/pair5/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 6
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay20_numtrials0_20250423_180755/pair6/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay20_numtrials0_20250423_180755/pair6/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 7
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay20_numtrials0_20250423_180755/pair7/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay20_numtrials0_20250423_180755/pair7/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 1
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay30_numtrials0_20250423_180854/pair1/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay30_numtrials0_20250423_180854/pair1/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 2
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay30_numtrials0_20250423_180854/pair2/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay30_numtrials0_20250423_180854/pair2/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 3
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay30_numtrials0_20250423_180854/pair3/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay30_numtrials0_20250423_180854/pair3/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 4
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay30_numtrials0_20250423_180854/pair4/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay30_numtrials0_20250423_180854/pair4/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 5
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay30_numtrials0_20250423_180854/pair5/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay30_numtrials0_20250423_180854/pair5/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 6
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay30_numtrials0_20250423_180854/pair6/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay30_numtrials0_20250423_180854/pair6/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 7
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay30_numtrials0_20250423_180854/pair7/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank40_delay30_numtrials0_20250423_180854/pair7/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 1
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay10_numtrials0_20250423_180951/pair1/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay10_numtrials0_20250423_180951/pair1/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 2
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay10_numtrials0_20250423_180951/pair2/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay10_numtrials0_20250423_180951/pair2/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 3
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay10_numtrials0_20250423_180951/pair3/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay10_numtrials0_20250423_180951/pair3/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 4
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay10_numtrials0_20250423_180951/pair4/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay10_numtrials0_20250423_180951/pair4/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 5
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay10_numtrials0_20250423_180951/pair5/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay10_numtrials0_20250423_180951/pair5/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 6
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay10_numtrials0_20250423_180951/pair6/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay10_numtrials0_20250423_180951/pair6/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 7
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay10_numtrials0_20250423_180951/pair7/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay10_numtrials0_20250423_180951/pair7/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 1
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay20_numtrials0_20250423_181117/pair1/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay20_numtrials0_20250423_181117/pair1/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 2
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay20_numtrials0_20250423_181117/pair2/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay20_numtrials0_20250423_181117/pair2/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 3
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay20_numtrials0_20250423_181117/pair3/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay20_numtrials0_20250423_181117/pair3/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 4
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay20_numtrials0_20250423_181117/pair4/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay20_numtrials0_20250423_181117/pair4/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 5
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay20_numtrials0_20250423_181117/pair5/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay20_numtrials0_20250423_181117/pair5/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 6
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay20_numtrials0_20250423_181117/pair6/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay20_numtrials0_20250423_181117/pair6/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 7
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay20_numtrials0_20250423_181117/pair7/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay20_numtrials0_20250423_181117/pair7/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 1
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay30_numtrials0_20250423_181248/pair1/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay30_numtrials0_20250423_181248/pair1/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 2
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay30_numtrials0_20250423_181248/pair2/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay30_numtrials0_20250423_181248/pair2/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 3
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay30_numtrials0_20250423_181248/pair3/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay30_numtrials0_20250423_181248/pair3/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 4
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay30_numtrials0_20250423_181248/pair4/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay30_numtrials0_20250423_181248/pair4/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 5
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay30_numtrials0_20250423_181248/pair5/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay30_numtrials0_20250423_181248/pair5/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 6
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay30_numtrials0_20250423_181248/pair6/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay30_numtrials0_20250423_181248/pair6/visualizations/contour.png
#
# Running bagoptDMD on PDE_KS pair 7
# Saved psd plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay30_numtrials0_20250423_181248/pair7/visualizations/psd.png
# Saved contour plot to /Users/sriva/Github/CTF-for-Science/results/PDE_KS/bagoptDMD/batch_rank60_delay30_numtrials0_20250423_181248/pair7/visualizations/contour.png

# %% [markdown]
# ## Post Processing and Plotting
# Let us load the results

# %%
from pathlib import Path
from ctf4science.eval_module import extract_metrics_in_order

# Dataset name
dataset_name = "PDE_KS"

# Dictionary to store results for all batches
results = {}

baseline_batches = [
    "CTF_NaiveBaselines_average/batch_avg_20250423_162739/",
]

model_batches = sorted(os.listdir("../../../results/PDE_KS/highorderDMD/"))
model_batches = ['highorderDMD/'+batch for batch in model_batches]
_model_batches = sorted(os.listdir("../../../results/PDE_KS/bagoptDMD/"))
model_batches += ['bagoptDMD/'+batch for batch in _model_batches]

all_batches = baseline_batches + model_batches

for batch in all_batches:
    # Construct the path to batch_results.yaml
    batch_dir = Path("../../../results") / dataset_name / batch
    batch_results_path = batch_dir / "batch_results.yaml"
    
    # Load the batch_results.yaml file
    with open(batch_results_path, "r") as f:
        batch_results = yaml.safe_load(f)
    
    # Extract metric values in the correct order
    metric_values = extract_metrics_in_order(dataset_name, batch_results)
    
    # Map values to E1, E2, ..., E12
    e_metrics = {f"E{i+1}": value for i, value in enumerate(metric_values)}
    
    # Store the transformed metrics with the batch path as the key
    results[batch] = e_metrics

# Optional: Display the results to verify
for batch, metrics in results.items():
    print(f"Batch: {batch}")
    print(metrics)
    print()
# Out:
# Batch: CTF_NaiveBaselines_average/batch_avg_20250423_162739/
# {'E1': -4.631336398781993, 'E2': 1.474626752441377, 'E3': 0.22272235606694002, 'E4': 1.214081593590377, 'E5': 2.6173207210912985, 'E6': 1.2701900910247477, 'E7': -0.5680211773671839, 'E8': 4.166696505654288, 'E9': -24.70958769561531, 'E10': 20.620923222521892}
# {'E1': -12.414288796184469, 'E2': 22.131066005129963, 'E3': 28.912563766054344, 'E4': -214.4564472672084, 'E5': 38.872593240546706, 'E6': 4.380287165283514, 'E7': -65.65950224724763, 'E8': 21.13913701703598, 'E9': -2791.6617585117615, 'E10': -809.817512056548}
#
# Batch: bagoptDMD/batch_rank40_delay30_numtrials0_20250423_180854
# {'E1': -39.783898928444785, 'E2': 26.924452686236688, 'E3': 27.634037762406027, 'E4': 15.037516018274022, 'E5': 29.7106964694973, 'E6': 3.3304993757433343, 'E7': -48.66217937809716, 'E8': -0.7081648850568278, 'E9': -65078643941182.85, 'E10': -9.425248978545118e+24}
#
# Batch: bagoptDMD/batch_rank60_delay10_numtrials0_20250423_180951
# {'E1': -10.390635431257046, 'E2': 23.650541827628214, 'E3': 38.556133871351975, 'E4': 34.374805360094165, 'E5': 45.00490930105907, 'E6': 17.728394631283205, 'E7': -1625.5473979736305, 'E8': -1827372.8289565803, 'E9': -104660127145047.25, 'E10': -1.5224557602925945e+26}
#
# Batch: bagoptDMD/batch_rank60_delay20_numtrials0_20250423_181117
# {'E1': -32.82649562977327, 'E2': 27.405942847937435, 'E3': 38.937115170146505, 'E4': -320.7375984092074, 'E5': 39.20091740907152, 'E6': 8.365456215799538, 'E7': -65.65950224724763, 'E8': 21.13913701703598, 'E9': -2791.6617585117615, 'E10': -809.817512056548}
#
# Batch: bagoptDMD/batch_rank60_delay30_numtrials0_20250423_181248
# {'E1': -66.88702729544347, 'E2': 31.126039145481332, 'E3': 37.11860168163514, 'E4': 17.951237486000014, 'E5': 46.77963421721862, 'E6': -90.17923539744532, 'E7': -48.66217937809716, 'E8': -0.7081648850568278, 'E9': -65078643941182.85, 'E10': -9.425248978545118e+24}

# %% [markdown]
# Let us make a spider plot

# %%
from matplotlib import cm
import matplotlib.pyplot as plt

def spider_plot(results, baseline_batches, model_batches, dataset_name,
                baseline_colormap = cm.jet_r, model_colormap = cm.plasma):

    categories = [f"E{i+1}" for i in range(10)]
    N = len(categories)

    # Create full batch paths
    all_batches = baseline_batches + model_batches
    
    # Generate colors for each batch
    baseline_colors = [baseline_colormap(i / len(baseline_batches)) for i in range(len(baseline_batches))]
    model_colors = [model_colormap(i / len(model_batches)) for i in range(len(model_batches))]
    colors = baseline_colors + model_colors

    # Create the figure and polar subplot
    fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(projection="polar"))

    # Plot each batch
    for i, batch_path in enumerate(all_batches):
        # Retrieve metrics (assuming results uses full paths as keys)
        values = list(results[str(batch_path)].values())
        # Close the plot by repeating the first value
        values += values[:1]
        # Calculate angles for the categories
        angles = np.linspace(0, 2 * np.pi, N, endpoint=False).tolist()
        angles += angles[:1]

        # Check values
        values = [v if v > -100 else -100 for v in values]
        
        # Plot the line and fill the area
        ax.plot(angles, values, label=all_batches[i], color=colors[i], alpha=0.7, marker='p', linestyle='--')
        ax.fill(angles, values, color=colors[i], alpha=0.1)
        
    # Set category labels
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(categories)
    
    # Set y-axis limits (assuming metrics are percentages; adjust if needed)
    ax.set_ylim(-100, 100)
    
    # Add a legend outside the plot
    ax.legend(loc="upper right", bbox_to_anchor=(1.7, 1.1))
    
    # Add a title
    ax.set_title(f"Performance Metrics E1 to E{N} ({dataset_name})", pad=20)
    
    # Display the plot
    plt.show()

spider_plot(results, baseline_batches, model_batches, dataset_name)
